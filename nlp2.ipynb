# %% [markdown]
# <a href="https://colab.research.google.com/github/ainankhan-pixel/NLP_Lab/blob/main/nlp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import twitter_samples
import matplotlib.pyplot as plt
import random

# %%
nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
import nltk
from nltk.corpus import twitter_samples

# %%
tweets=twitter_samples.strings()

# %%
type(tweets)
# Out:
# list

# %%
len(tweets)
# Out:
# 30000

# %%
import pandas as pd
all_tweets=pd.DataFrame(tweets, columns=["Tweets"])
all_tweets.tail()
# Out:
#                                                   Tweets
# 29995  RT @UKLabour: .@Ed_Miliband: we're not going t...
# 29996  RT @DisabledScot: @blairmcdougall @ScotlandTon...
# 29997  RT @Staircase2: @VividRicky exactly but that a...
# 29998  Actually agreed with %95 of what farage was sa...
# 29999  RT @PeatWorrier: "A vote for the SNP is. Er. A...

# %%
"len of first",len(tweets[0])
# Out:
# ('len of first', 19)

# %%
twitter_samples.fileids()
# Out:
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']

# %%
pos_tweets=twitter_samples.strings("positive_tweets.json")
neg_tweets=twitter_samples.strings("negative_tweets.json")

# %%
len(pos_tweets)
# Out:
# 5000

# %%
len(neg_tweets)
# Out:
# 5000

# %%
pos_tweets=pd.DataFrame(pos_tweets, columns=["Tweets"])
pos_tweets["Sentiments"]="Positive"
pos_tweets.tail()
# Out:
#                                                  Tweets Sentiments
# 4995  @chriswiggin3 Chris, that's great to hear :) D...   Positive
# 4996  @RachelLiskeard Thanks for the shout-out :) It...   Positive
# 4997            @side556 Hey!  :)  Long time no talk...   Positive
# 4998  @staybubbly69 as Matt would say. WELCOME TO AD...   Positive
# 4999  @DanielOConnel18 you could say he will have eg...   Positive

# %%
neg_tweets=pd.DataFrame(neg_tweets, columns=["Tweets"])
neg_tweets["Sentiments"]="Negative"
neg_tweets.tail()
# Out:
#                                                  Tweets Sentiments
# 4995               I wanna change my avi but uSanele :(   Negative
# 4996                         MY PUPPY BROKE HER FOOT :(   Negative
# 4997           where's all the jaebum baby pictures :((   Negative
# 4998  But but Mr Ahmad Maslan cooks too :( https://t...   Negative
# 4999  @eawoman As a Hull supporter I am expecting a ...   Negative

# %%
tweets=pd.concat([pos_tweets,neg_tweets],ignore_index=False)
tweets=tweets.sample(frac=1).reset_index(drop=True)
tweets
# Out:
#                                                  Tweets Sentiments
# 0          @seanactual You mean you're not offering? :(   Negative
# 1     @Louis_Tomlinson school start next Monday ohgo...   Negative
# 2     @aldriannetabang  follow @jnlazts &amp; http:/...   Positive
# 3                       @ItzBabyAlexa :((( love ya 2 😭💖   Negative
# 4     @calumscool @carterreynolds Stop getting hate ...   Positive
# ...                                                 ...        ...
# 9995               so wtf should I do today ?.....:((((   Negative
# 9996                    @Taylor_Marisa Follow back ? :)   Positive
# 9997  @donnaledesma_ from PHL to Abu Dhabi, with lov...   Positive
# 9998  cant believe I missed your follow spree today ...   Negative
# 9999  @curlsharryxoxo i don't know :(( just be happy...   Negative
#
# [10000 rows x 2 columns]

# %%
import numpy as np
tweets[tweets["Sentiments"]=="Positive"].value_counts().sum()
tweets[tweets["Sentiments"]=="Negative"].value_counts().sum()
# Out:
# np.int64(5000)

# %%
y_positive=(tweets["Sentiments"]=="Positive").sum()
y_negative=(tweets["Sentiments"]=="Negative").sum()
print(y_positive,y_negative)
# Out:
# 5000 5000

# %%
tweet1=all_tweets.iloc[1000]
tweet1["Tweets"]
# Out:
# "@seanactual You mean you're not offering? :("

# %% [markdown]
# #visualization

# %%
fig=plt.figure(figsize=(2,4))
labels=["Positive","Negative"]
sizes=[y_positive,y_negative]
plt.bar(labels,sizes)
plt.show()

# %% [markdown]
# #Preprocess raw text for Sentiment analysis

# %%
tweet1=all_tweets.iloc[1000]
tweet1["Tweets"]
# Out:
# "@seanactual You mean you're not offering? :("

# %%
import re
import string
from  nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
# remove old style retweet text "RT"
tweet2=re.sub(r'^RT[\s]+','', tweet1["Tweets"])

# remove hyperlinks
tweet2=re.sub(r'https?://[^\s\n\r]+','', tweet2)

# remove hashtags (only removing the hash # sign from the word)
tweet2 = re.sub(r'#\w+','', tweet2)
# remove mentions
tweet2 = re.sub(r'@\w+','', tweet2)
# remove specific punctuation/emojis like :), :(, etc.
tweet2 = re.sub(r'[():]','', tweet2)

print(tweet1["Tweets"])
print("\nCleaned tweet: \n", tweet2)
# Out:
# @seanactual You mean you're not offering? :(
#
# Cleaned tweet:
#   You mean you're not offering?

# %%
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True) # instantiate tokenizer class

# tokenize tweets
tweet_tokens = tokenizer.tokenize(tweet2)

print()
print("Tokenized string:\n")
print(tweet_tokens)
# Out:
# Tokenized string:
#
# ['you', 'mean', "you're", 'not', 'offering', '?']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
 nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#import the english stop words list from NLIK
stopwords_english = stopwords.words('english')

print('Stop words\n')
print(stopwords_english)

print('\nPunctuation\n')
print(string.punctuation)
# Out:
# Stop words
#
# ...

# %%
print("Ainan Khan", "UIN: 231A052\n")
print(tweet_tokens)
print()
# print('\033[94m')

tweets_clean = []

for word in tweet_tokens: # Go through every word in your tokens list
    # remove stopwords and punctuation
    if (word not in stopwords_english and word not in string.punctuation):
        tweets_clean.append(word)

print('removed stop words and punctuation:')
print(tweets_clean)
# Out:
# Ainan Khan UIN: 231A052
#
# ['you', 'mean', "you're", 'not', 'offering', '?']
#
# removed stop words and punctuation:
# ['mean', 'offering']

# %%
print("Ainan Khan", "UIN: 231A052\n")
def process_tweet(tweet):
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)


    tweet = re.sub(r'^RT[\s]+','', tweet)


    tweet = re.sub(r'https?://[^\s\n\r]+','', tweet)

    tweet = re.sub(r'#\w+','', tweet)
    tweet = re.sub(r'@\w+','', tweet)
    tweet = re.sub(r'[():]','', tweet)

    tweet_tokens = tokenizer.tokenize(tweet)

    stopwords_english = stopwords.words('english')
    tweets_clean = []

    for word in tweet_tokens:

        if (word not in stopwords_english and word not in string.punctuation):
            tweets_clean.append(word)

    return tweets_clean

# %%
print("Ainan Khan", "UIN: 231A052\n")
tweet1=all_tweets.iloc[746]
tweet=tweet1["Tweets"]
print(process_tweet(tweet))
# Out:
# Ainan Khan UIN: 231A052
#
# ['omg', 'love', 'ty', 'zap']

# %%
print("Ainan Khan", "UIN: 231A052\n")
processed_tweets=all_tweets['Tweets'].apply(process_tweet)
all_tweets['Tweets_processed']=processed_tweets
pd.set_option('display.max_colwidth', None)
all_tweets
# Out:
# Ainan Khan UIN: 231A052
#                                                                                                                                               Tweets  \
# 0                                                                                                                                hopeless for tmr :(
# 1                                                              Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(
# 2                                                                                             @Hegelbon That heart sliding into the waste basket. :(
# 3                                                                                   “@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too
# 4                                                                                                           Dang starting next week I have "work" :(
# ...

# %%
print("Ainan Khan", "UIN: 231A052\n")
tweets["cleaned_text"] = tweets["Tweets"].apply(lambda x: " ".join(process_tweet(x)))
processed_tweets_with_sentiments = tweets[["cleaned_text", "Sentiments"]]
processed_tweets_with_sentiments.head()
# Out:
# Ainan Khan UIN: 231A052
#                                                          cleaned_text  \
# 0                                                       mean offering
# 1                                      school start next monday ohgod
# 2                                                follow follow u back
# 3                                                       love ya 2 😭 💖
# 4  stop getting hate whatever kind is.he made mistake understood stop
#
#   Sentiments
# 0   Negative
# 1   Negative
# 2   Positive
# 3   Negative
# 4   Positive

# %%
print("Ainan Khan", "UIN: 231A052\n")
all_tweets["Tweets_cleaned_joined"] = all_tweets["Tweets_processed"].apply(lambda x: " ".join(x))
processed_tweets_all2 = all_tweets[["Tweets_cleaned_joined"]]
processed_tweets_all2.head()
# Out:
# Ainan Khan UIN: 231A052
#                                         Tweets_cleaned_joined
# 0                                                hopeless tmr
# 1  everything kids section ikea cute shame nearly 19 2 months
# 2                                  heart sliding waste basket
# 3                                 “ hate japanese call bani ”
# 4                                dang starting next week work
