# %% [markdown]
# <a href="https://colab.research.google.com/github/ainankhan-pixel/231A052_NLP_Lab/blob/main/NLPexp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="I was Computing."

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string

# %%
print("Name=Ainan Khan  UIN=231A052")
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# Name=Ainan Khan  UIN=231A052
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
print("Name=Ainan Khan  UIN=231A052")
print(string.punctuation)
# Out:
# Name=Ainan Khan  UIN=231A052
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print("Name=Ainan Khan  UIN=231A052")
text_lower=text.lower()
print(text_lower)
# Out:
# Name=Ainan Khan  UIN=231A052
# i was computing.

# %%
print("Name=Ainan Khan  UIN=231A052")
import nltk
nltk.download('punkt_tab')
tokens=word_tokenize(text_lower)
print(tokens)
# Out:
# Name=Ainan Khan  UIN=231A052
# ['i', 'was', 'computing', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
print("Name=Ainan Khan  UIN=231A052")

text_clean=[]
for words in tokens:
  if words not in string.punctuation:
    text_clean.append(words)
print(text_clean)
# Out:
# Name=Ainan Khan  UIN=231A052
# ['i', 'was', 'computing']

# %%
print("Name=Ainan Khan  UIN=231A052")

lemmatizer=WordNetLemmatizer()
lemmas=[lemmatizer.lemmatize(tok, pos='v')for tok in text_clean]
print(lemmas)
# Out:
# Name=Ainan Khan  UIN=231A052
# ['i', 'be', 'compute']

# %%
print("Name=Ainan Khan  UIN=231A052")
lemmatizer.lemmatize('computer', pos='v')
# Out:
# Name=Ainan Khan  UIN=231A052
# 'computer'

# %%
print("Name=Ainan Khan  UIN=231A052")
[(token, lemma)for token,lemma in zip(tokens, lemmas)]
# Out:
# Name=Ainan Khan  UIN=231A052
# [('i', 'i'), ('was', 'be'), ('computing', 'compute')]

# %%
print("Name=Ainan Khan  UIN=231A052")
morphological_info = {}
for token, lemma in zip(text_clean, lemmas):
    if token != lemma:
        # This indicates some morphological change
        if token.endswith("ing"):
            analysis = "Inflectional: Present participle/continuous form of '{}'".format(lemma)
        elif token.endswith("er") or token.endswith("ation"):
            analysis = "Derivational: '{}' + er person who does the action".format(lemma)
        else:
            analysis = "Inflectional or irregular form of '{}'".format(lemma)
    else:
        analysis = "Base/root form"
    morphological_info[token] = analysis
print(morphological_info)
# Out:
# Name=Ainan Khan  UIN=231A052
# {'i': 'Base/root form', 'was': "Inflectional or irregular form of 'be'", 'computing': "Inflectional: Present participle/continuous form of 'compute'"}
